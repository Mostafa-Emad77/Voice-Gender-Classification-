# %% [markdown]
# # Audio Processing Pipeline
#
# *This is the first notebook out of three notebooks focused on preprocessing the data.*
#
# ## 1. Converting Audio Files
# - **Objective:** Convert audio files into a standardized format for further processing.
# - **Techniques:**
#   - Load audio files in various formats (e.g., WAV, MP3) and convert them to a uniform format (e.g., WAV at a consistent sampling rate).
#   - Ensure all audio files have a standard bitrate and channel configuration (e.g., mono).
#
# ## 2. Voice Activity Detection (VAD)
# - **Objective:** Detect when speech is occurring and segment the audio accordingly.
# - **Model:** Use the **Silero VAD** pre-trained model for detecting voice activity.
# - **Steps:**
#   - Load the Silero VAD model.
#   - Apply the VAD to segment portions of the audio where speech is detected.
#   - Discard or mark non-speech regions.
#
# ## 3. Processing the Audio Files
# - **Objective:** Clean and standardize the audio input by addressing:
#   - Background noise
#   - Long silences
#   - Sudden volume changes
#   - Inconsistent audio lengths
# - **Techniques:**
#   - Noise reduction using filters (e.g., spectral gating, noise profiling).
#   - Silence removal or trimming long pauses.
#   - Normalizing audio volume to handle inconsistencies.
#   - Padding or trimming to ensure consistent audio length.
#
# ## 4. Data Augmentation
# - **Objective:** Enhance the dataset to improve model robustness and generalization.
# - **Techniques:**
#   - Apply pitch shifting to alter the frequency of the audio.
#   - Use time stretching to modify the speed of the audio without affecting pitch.
#   - Create variations of existing audio samples through random transformations.

# %% [markdown]
# ## Importing libraries

# %%
import warnings
warnings.filterwarnings('ignore')
# Data processing
import pandas as pd
import math
import numpy as np
import librosa
import os
from collections import Counter
from pydub import AudioSegment
from IPython.display import Audio
from pprint import pprint
import noisereduce as nr
import subprocess
import soundfile as sf
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import librosa.display
# Model and performance
import torch

# %% [markdown]
# ## 1. Converting Audio Files

# %%
def convert_m4a_to_wav(input_folder):
    for audio_file in os.listdir(input_folder):
        if audio_file.endswith(".m4a"):
            file_path = os.path.join(input_folder, audio_file)
            output_file_path = os.path.splitext(file_path)[0] + ".wav"
            subprocess.run(['ffmpeg', '-i', file_path, output_file_path])

# %%
def delete_m4a_files(folder_path):
    for audio_file in os.listdir(folder_path):
        if audio_file.endswith(".m4a"):
            file_path = os.path.join(folder_path, audio_file)
            os.remove(file_path)  # Delete the file
            print(f"Deleted: {file_path}")

# %%
root_folder = "VoxCeleb_gender"
male_folder = os.path.join(root_folder, "males")
female_folder = os.path.join(root_folder, "females")

# %%
convert_m4a_to_wav(male_folder)
convert_m4a_to_wav(female_folder)

# %%
delete_m4a_files(male_folder)
delete_m4a_files(female_folder)

# %% [markdown]
# # Calculating the average length of audio files

# %%
def calculate_average_length(input_folder):
    total_length = 0
    audio_count = 0

    for audio_file in os.listdir(input_folder):
        if audio_file.endswith((".wav")):  # Accept both .wav and .m4a files
            file_path = os.path.join(input_folder, audio_file)
            audio = AudioSegment.from_file(file_path)
            total_length += len(audio) / 1000.0  # Length is in milliseconds, convert to seconds
            audio_count += 1

    if audio_count > 0:
        average_length = total_length / audio_count
    else:
        average_length = 0

    return average_length

# %%
average_length_male = calculate_average_length(male_folder)
average_length_female = calculate_average_length(female_folder)

print(f"Average audio length for male files: {average_length_male:.2f} seconds")
print(f"Average audio length for female files: {average_length_female:.2f} seconds")
# Out:
# Average audio length for male files: 6.89 seconds
# Average audio length for female files: 7.16 seconds

# %% [markdown]
# ## 2. Voice Activity Detection (VAD)

# %%
def create_output_folders(base_folder):
    male_output_folder = os.path.join(base_folder, "male_vad_results")
    female_output_folder = os.path.join(base_folder, "female_vad_results")

    os.makedirs(male_output_folder, exist_ok=True)
    os.makedirs(female_output_folder, exist_ok=True)

    return male_output_folder, female_output_folder

def apply_vad_to_audio(input_folder, output_folder):
    for audio_file in os.listdir(input_folder):
        if audio_file.endswith((".wav", ".m4a")):  # Accept both .wav and .m4a files
            file_path = os.path.join(input_folder, audio_file)
            sampling_rate = 16000  # Set the sampling rate
            wav = read_audio(file_path, sampling_rate=sampling_rate)  # Read audio file
            
            # Get speech timestamps from the audio
            speech_timestamps = get_speech_timestamps(wav, model, sampling_rate=sampling_rate)
            
            print(f"Speech timestamps for {audio_file}: {speech_timestamps}")
            
            combined_segments = []
            
            for segment in speech_timestamps:
                try:
                    start = int(segment['start'])  # Access start from dictionary
                    end = int(segment['end'])      # Access end from dictionary
                except ValueError as e:
                    print(f"Error converting timestamps for {audio_file}: {e}")
                    continue

                speech_segment = wav[start:end]
                combined_segments.append(speech_segment)  # Store the segment for combining

            # Combine all speech segments into a single audio
            if combined_segments:
                combined_audio = np.concatenate(combined_segments)  # Combine segments
                output_audio_file = os.path.join(output_folder, f"{os.path.splitext(audio_file)[0]}_combined.wav")
                sf.write(output_audio_file, combined_audio, sampling_rate)  

                print(f"Saved combined VAD segments for {audio_file} to {output_audio_file}")
            else:
                print(f"No segments found for {audio_file}, skipping...")

# %%
torch.set_num_threads(1)

# Load the VAD model
model, utils = torch.hub.load(repo_or_dir='snakers4/silero-vad',
                               model='silero_vad',
                               force_reload=True)


# Unpack the necessary functions from utils
get_speech_timestamps = utils[0]
read_audio = utils[2]

base_folder = "VoxCeleb_gender"  # Adjust this as needed

male_output_folder, female_output_folder = create_output_folders(base_folder)

male_folder = os.path.join(base_folder, "males")  # Path to male audio folder
female_folder = os.path.join(base_folder, "females")  # Path to female audio folder

apply_vad_to_audio(male_folder, male_output_folder)
apply_vad_to_audio(female_folder, female_output_folder)
# Out:
# Downloading: "https://github.com/snakers4/silero-vad/zipball/master" to C:\Users\Mostafa/.cache\torch\hub\master.zip
# Speech timestamps for 0.wav: [{'start': 0, 'end': 88064}]
# Saved combined VAD segments for 0.wav to VoxCeleb_gender\male_vad_results\0_combined.wav
# Speech timestamps for 1.wav: [{'start': 7712, 'end': 26080}, {'start': 31264, 'end': 60896}, {'start': 64032, 'end': 87520}, {'start': 90656, 'end': 113632}, {'start': 116768, 'end': 143328}, {'start': 145440, 'end': 155648}]
# Saved combined VAD segments for 1.wav to VoxCeleb_gender\male_vad_results\1_combined.wav
# Speech timestamps for 10.wav: [{'start': 0, 'end': 393216}]
# Saved combined VAD segments for 10.wav to VoxCeleb_gender\male_vad_results\10_combined.wav
# Speech timestamps for 100.wav: [{'start': 0, 'end': 79872}]
# Saved combined VAD segments for 100.wav to VoxCeleb_gender\male_vad_results\100_combined.wav
# Speech timestamps for 1000.wav: [{'start': 544, 'end': 66560}]
# Saved combined VAD segments for 1000.wav to VoxCeleb_gender\male_vad_results\1000_combined.wav
# Speech timestamps for 1001.wav: [{'start': 6176, 'end': 47584}, {'start': 52768, 'end': 66560}]
# Saved combined VAD segments for 1001.wav to VoxCeleb_gender\male_vad_results\1001_combined.wav
# Speech timestamps for 1002.wav: [{'start': 4640, 'end': 88064}]
# Saved combined VAD segments for 1002.wav to VoxCeleb_gender\male_vad_results\1002_combined.wav
# Speech timestamps for 1003.wav: [{'start': 544, 'end': 74720}, {'start': 77344, 'end': 134624}, {'start': 136224, 'end': 177120}]
# Saved combined VAD segments for 1003.wav to VoxCeleb_gender\male_vad_results\1003_combined.wav
# Speech timestamps for 1004.wav: [{'start': 0, 'end': 67584}]
# Saved combined VAD segments for 1004.wav to VoxCeleb_gender\male_vad_results\1004_combined.wav
# Speech timestamps for 1005.wav: [{'start': 0, 'end': 36832}, {'start': 41504, 'end': 66528}, {'start': 69152, 'end': 116704}, {'start': 119840, 'end': 159200}, {'start': 162336, 'end': 265696}, {'start': 268320, 'end': 287744}]
# Saved combined VAD segments for 1005.wav to VoxCeleb_gender\male_vad_results\1005_combined.wav
# Speech timestamps for 1006.wav: [{'start': 0, 'end': 45024}, {'start': 47136, 'end': 77824}]
# Saved combined VAD segments for 1006.wav to VoxCeleb_gender\male_vad_results\1006_combined.wav
# Speech timestamps for 1007.wav: [{'start': 0, 'end': 6624}, {'start': 8736, 'end': 99296}, {'start': 101408, 'end': 145408}]
# Saved combined VAD segments for 1007.wav to VoxCeleb_gender\male_vad_results\1007_combined.wav
# Speech timestamps for 1008.wav: [{'start': 0, 'end': 33760}, {'start': 38944, 'end': 81376}]
# Saved combined VAD segments for 1008.wav to VoxCeleb_gender\male_vad_results\1008_combined.wav
# Speech timestamps for 1009.wav: [{'start': 0, 'end': 75776}]
# Saved combined VAD segments for 1009.wav to VoxCeleb_gender\male_vad_results\1009_combined.wav
# Speech timestamps for 101.wav: [{'start': 0, 'end': 219616}, {'start': 221216, 'end': 235520}]
# Saved combined VAD segments for 101.wav to VoxCeleb_gender\male_vad_results\101_combined.wav
# Speech timestamps for 1010.wav: [{'start': 4640, 'end': 63488}]
# Saved combined VAD segments for 1010.wav to VoxCeleb_gender\male_vad_results\1010_combined.wav
# Speech timestamps for 1011.wav: [{'start': 0, 'end': 64512}]
# Saved combined VAD segments for 1011.wav to VoxCeleb_gender\male_vad_results\1011_combined.wav
# Speech timestamps for 1012.wav: [{'start': 7712, 'end': 63488}]
# Saved combined VAD segments for 1012.wav to VoxCeleb_gender\male_vad_results\1012_combined.wav
# Speech timestamps for 1013.wav: [{'start': 32, 'end': 70656}]
# Saved combined VAD segments for 1013.wav to VoxCeleb_gender\male_vad_results\1013_combined.wav
# Speech timestamps for 1014.wav: [{'start': 0, 'end': 54752}, {'start': 63008, 'end': 99328}]
# Saved combined VAD segments for 1014.wav to VoxCeleb_gender\male_vad_results\1014_combined.wav
# Speech timestamps for 1015.wav: [{'start': 0, 'end': 113632}, {'start': 115232, 'end': 155648}]
# Saved combined VAD segments for 1015.wav to VoxCeleb_gender\male_vad_results\1015_combined.wav
# Speech timestamps for 1016.wav: [{'start': 544, 'end': 68608}]
# Saved combined VAD segments for 1016.wav to VoxCeleb_gender\male_vad_results\1016_combined.wav
# Speech timestamps for 1017.wav: [{'start': 32, 'end': 28128}, {'start': 29728, 'end': 152032}, {'start': 154144, 'end': 370688}]
# Saved combined VAD segments for 1017.wav to VoxCeleb_gender\male_vad_results\1017_combined.wav
# Speech timestamps for 1018.wav: [{'start': 544, 'end': 71680}]
# Saved combined VAD segments for 1018.wav to VoxCeleb_gender\male_vad_results\1018_combined.wav
# Speech timestamps for 1019.wav: [{'start': 544, 'end': 103424}]
# Saved combined VAD segments for 1019.wav to VoxCeleb_gender\male_vad_results\1019_combined.wav
# Speech timestamps for 102.wav: [{'start': 0, 'end': 22496}, {'start': 24096, 'end': 161792}]
# Saved combined VAD segments for 102.wav to VoxCeleb_gender\male_vad_results\102_combined.wav
# Speech timestamps for 1020.wav: [{'start': 2080, 'end': 63488}]
# Saved combined VAD segments for 1020.wav to VoxCeleb_gender\male_vad_results\1020_combined.wav
# Speech timestamps for 1021.wav: [{'start': 0, 'end': 62944}, {'start': 64544, 'end': 98304}]
# Saved combined VAD segments for 1021.wav to VoxCeleb_gender\male_vad_results\1021_combined.wav
# Speech timestamps for 1022.wav: [{'start': 0, 'end': 63456}, {'start': 66080, 'end': 77824}]
# Saved combined VAD segments for 1022.wav to VoxCeleb_gender\male_vad_results\1022_combined.wav
# Speech timestamps for 1023.wav: [{'start': 7712, 'end': 66560}]
# Saved combined VAD segments for 1023.wav to VoxCeleb_gender\male_vad_results\1023_combined.wav
# Speech timestamps for 1024.wav: [{'start': 0, 'end': 67584}]
# Saved combined VAD segments for 1024.wav to VoxCeleb_gender\male_vad_results\1024_combined.wav
# Speech timestamps for 1025.wav: [{'start': 1056, 'end': 23008}, {'start': 27680, 'end': 49120}, {'start': 52256, 'end': 73728}]
# Saved combined VAD segments for 1025.wav to VoxCeleb_gender\male_vad_results\1025_combined.wav
# Speech timestamps for 1026.wav: [{'start': 3616, 'end': 172032}]
# Saved combined VAD segments for 1026.wav to VoxCeleb_gender\male_vad_results\1026_combined.wav
# Speech timestamps for 1027.wav: [{'start': 0, 'end': 63488}]
# Saved combined VAD segments for 1027.wav to VoxCeleb_gender\male_vad_results\1027_combined.wav
# Speech timestamps for 1028.wav: [{'start': 0, 'end': 18912}, {'start': 24608, 'end': 66560}]
# Saved combined VAD segments for 1028.wav to VoxCeleb_gender\male_vad_results\1028_combined.wav
# Speech timestamps for 1029.wav: [{'start': 2080, 'end': 169984}]
# Saved combined VAD segments for 1029.wav to VoxCeleb_gender\male_vad_results\1029_combined.wav
# Speech timestamps for 103.wav: [{'start': 5664, 'end': 18400}, {'start': 22560, 'end': 73728}]
# Saved combined VAD segments for 103.wav to VoxCeleb_gender\male_vad_results\103_combined.wav
# Speech timestamps for 1030.wav: [{'start': 1056, 'end': 58848}, {'start': 60960, 'end': 138240}]
# Saved combined VAD segments for 1030.wav to VoxCeleb_gender\male_vad_results\1030_combined.wav
# Speech timestamps for 1031.wav: [{'start': 0, 'end': 67584}]
# Saved combined VAD segments for 1031.wav to VoxCeleb_gender\male_vad_results\1031_combined.wav
# Speech timestamps for 1032.wav: [{'start': 0, 'end': 61920}, {'start': 64032, 'end': 73728}]
# Saved combined VAD segments for 1032.wav to VoxCeleb_gender\male_vad_results\1032_combined.wav
# Speech timestamps for 1033.wav: [{'start': 1568, 'end': 17376}, {'start': 25632, 'end': 44512}, {'start': 49184, 'end': 65504}, {'start': 72224, 'end': 90592}, {'start': 95776, 'end': 113664}]
# Saved combined VAD segments for 1033.wav to VoxCeleb_gender\male_vad_results\1033_combined.wav
# Speech timestamps for 1034.wav: [{'start': 6688, 'end': 101344}, {'start': 105504, 'end': 129024}]
# Saved combined VAD segments for 1034.wav to VoxCeleb_gender\male_vad_results\1034_combined.wav
# Speech timestamps for 1035.wav: [{'start': 0, 'end': 63488}]
# Saved combined VAD segments for 1035.wav to VoxCeleb_gender\male_vad_results\1035_combined.wav
# Speech timestamps for 1036.wav: [{'start': 0, 'end': 106496}]
# Saved combined VAD segments for 1036.wav to VoxCeleb_gender\male_vad_results\1036_combined.wav
# Speech timestamps for 1037.wav: [{'start': 0, 'end': 70656}]
# Saved combined VAD segments for 1037.wav to VoxCeleb_gender\male_vad_results\1037_combined.wav
# Speech timestamps for 1038.wav: [{'start': 5152, 'end': 68608}]
# Saved combined VAD segments for 1038.wav to VoxCeleb_gender\male_vad_results\1038_combined.wav
# Speech timestamps for 1039.wav: [{'start': 1056, 'end': 72704}]
# Saved combined VAD segments for 1039.wav to VoxCeleb_gender\male_vad_results\1039_combined.wav
# Speech timestamps for 104.wav: [{'start': 1056, 'end': 33248}, {'start': 35360, 'end': 71680}]
# Saved combined VAD segments for 104.wav to VoxCeleb_gender\male_vad_results\104_combined.wav
# Speech timestamps for 1040.wav: [{'start': 0, 'end': 116192}, {'start': 119840, 'end': 192512}]
# Saved combined VAD segments for 1040.wav to VoxCeleb_gender\male_vad_results\1040_combined.wav
# Speech timestamps for 1041.wav: [{'start': 0, 'end': 119808}]
# Saved combined VAD segments for 1041.wav to VoxCeleb_gender\male_vad_results\1041_combined.wav
# Speech timestamps for 1042.wav: [{'start': 2592, 'end': 61920}, {'start': 69152, 'end': 99808}, {'start': 103456, 'end': 108544}]
# Saved combined VAD segments for 1042.wav to VoxCeleb_gender\male_vad_results\1042_combined.wav
# Speech timestamps for 1043.wav: [{'start': 32, 'end': 72672}, {'start': 82464, 'end': 98304}]
# Saved combined VAD segments for 1043.wav to VoxCeleb_gender\male_vad_results\1043_combined.wav
# Speech timestamps for 1044.wav: [{'start': 32, 'end': 7648}, {'start': 10784, 'end': 45024}, {'start': 51232, 'end': 63488}]
# Saved combined VAD segments for 1044.wav to VoxCeleb_gender\male_vad_results\1044_combined.wav
# Speech timestamps for 1045.wav: [{'start': 9760, 'end': 116736}]
# Saved combined VAD segments for 1045.wav to VoxCeleb_gender\male_vad_results\1045_combined.wav
# Speech timestamps for 1046.wav: [{'start': 0, 'end': 63488}]
# Saved combined VAD segments for 1046.wav to VoxCeleb_gender\male_vad_results\1046_combined.wav
# Speech timestamps for 1047.wav: [{'start': 544, 'end': 49632}, {'start': 58400, 'end': 73728}]
# Saved combined VAD segments for 1047.wav to VoxCeleb_gender\male_vad_results\1047_combined.wav
# Speech timestamps for 1048.wav: [{'start': 5152, 'end': 36320}, {'start': 42016, 'end': 60384}, {'start': 64032, 'end': 86016}]
# Saved combined VAD segments for 1048.wav to VoxCeleb_gender\male_vad_results\1048_combined.wav
# Speech timestamps for 1049.wav: [{'start': 0, 'end': 70624}, {'start': 72224, 'end': 159744}]
# Saved combined VAD segments for 1049.wav to VoxCeleb_gender\male_vad_results\1049_combined.wav
# Speech timestamps for 105.wav: [{'start': 1568, 'end': 127968}, {'start': 137248, 'end': 174080}]
# Saved combined VAD segments for 105.wav to VoxCeleb_gender\male_vad_results\105_combined.wav
# Speech timestamps for 1050.wav: [{'start': 0, 'end': 25568}, {'start': 32288, 'end': 80352}, {'start': 84000, 'end': 105952}, {'start': 110112, 'end': 132576}, {'start': 134688, 'end': 172512}, {'start': 180256, 'end': 191488}]
# Saved combined VAD segments for 1050.wav to VoxCeleb_gender\male_vad_results\1050_combined.wav
# Speech timestamps for 1051.wav: [{'start': 4128, 'end': 61408}, {'start': 71712, 'end': 98304}]
# Saved combined VAD segments for 1051.wav to VoxCeleb_gender\male_vad_results\1051_combined.wav
# Speech timestamps for 1052.wav: [{'start': 544, 'end': 85984}]
# Saved combined VAD segments for 1052.wav to VoxCeleb_gender\male_vad_results\1052_combined.wav
# Speech timestamps for 1053.wav: [{'start': 0, 'end': 48096}, {'start': 49696, 'end': 99328}]
# Saved combined VAD segments for 1053.wav to VoxCeleb_gender\male_vad_results\1053_combined.wav
# Speech timestamps for 1054.wav: [{'start': 3104, 'end': 68608}]
# Saved combined VAD segments for 1054.wav to VoxCeleb_gender\male_vad_results\1054_combined.wav
# Speech timestamps for 1055.wav: [{'start': 32, 'end': 95232}]
# Saved combined VAD segments for 1055.wav to VoxCeleb_gender\male_vad_results\1055_combined.wav
# Speech timestamps for 1056.wav: [{'start': 0, 'end': 77824}]
# Saved combined VAD segments for 1056.wav to VoxCeleb_gender\male_vad_results\1056_combined.wav
# Speech timestamps for 1057.wav: [{'start': 5664, 'end': 68576}, {'start': 76832, 'end': 98304}]
# Saved combined VAD segments for 1057.wav to VoxCeleb_gender\male_vad_results\1057_combined.wav
# Speech timestamps for 1058.wav: [{'start': 4128, 'end': 82944}]
# Saved combined VAD segments for 1058.wav to VoxCeleb_gender\male_vad_results\1058_combined.wav
# Speech timestamps for 1059.wav: [{'start': 32, 'end': 37344}, {'start': 43040, 'end': 89088}]
# Saved combined VAD segments for 1059.wav to VoxCeleb_gender\male_vad_results\1059_combined.wav
# Speech timestamps for 106.wav: [{'start': 32, 'end': 39392}, {'start': 42528, 'end': 63488}]
# Saved combined VAD segments for 106.wav to VoxCeleb_gender\male_vad_results\106_combined.wav
# Speech timestamps for 1060.wav: [{'start': 1056, 'end': 72704}]
# Saved combined VAD segments for 1060.wav to VoxCeleb_gender\male_vad_results\1060_combined.wav
# Speech timestamps for 1061.wav: [{'start': 0, 'end': 38880}, {'start': 44064, 'end': 106496}]
# Saved combined VAD segments for 1061.wav to VoxCeleb_gender\male_vad_results\1061_combined.wav
# Speech timestamps for 1062.wav: [{'start': 3104, 'end': 26592}, {'start': 29216, 'end': 43488}, {'start': 46624, 'end': 84960}, {'start': 89632, 'end': 98784}, {'start': 104992, 'end': 128992}, {'start': 132640, 'end': 143328}, {'start': 146976, 'end': 196608}]
# Saved combined VAD segments for 1062.wav to VoxCeleb_gender\male_vad_results\1062_combined.wav
# Speech timestamps for 1063.wav: [{'start': 0, 'end': 108544}]
# Saved combined VAD segments for 1063.wav to VoxCeleb_gender\male_vad_results\1063_combined.wav
# Speech timestamps for 1064.wav: [{'start': 1568, 'end': 72704}]
# Saved combined VAD segments for 1064.wav to VoxCeleb_gender\male_vad_results\1064_combined.wav
# Speech timestamps for 1065.wav: [{'start': 32, 'end': 125920}, {'start': 128032, 'end': 309248}]
# Saved combined VAD segments for 1065.wav to VoxCeleb_gender\male_vad_results\1065_combined.wav
# Speech timestamps for 1066.wav: [{'start': 0, 'end': 74752}]
# Saved combined VAD segments for 1066.wav to VoxCeleb_gender\male_vad_results\1066_combined.wav
# Speech timestamps for 1067.wav: [{'start': 0, 'end': 66560}]
# Saved combined VAD segments for 1067.wav to VoxCeleb_gender\male_vad_results\1067_combined.wav
# Speech timestamps for 1068.wav: [{'start': 0, 'end': 40416}, {'start': 44576, 'end': 69632}]
# Saved combined VAD segments for 1068.wav to VoxCeleb_gender\male_vad_results\1068_combined.wav
# Speech timestamps for 1069.wav: [{'start': 544, 'end': 76800}]
# Saved combined VAD segments for 1069.wav to VoxCeleb_gender\male_vad_results\1069_combined.wav
# Speech timestamps for 107.wav: [{'start': 1056, 'end': 11744}, {'start': 14368, 'end': 200704}]
# Saved combined VAD segments for 107.wav to VoxCeleb_gender\male_vad_results\107_combined.wav
# Speech timestamps for 1070.wav: [{'start': 0, 'end': 100352}]
# Saved combined VAD segments for 1070.wav to VoxCeleb_gender\male_vad_results\1070_combined.wav
# Speech timestamps for 1071.wav: [{'start': 0, 'end': 19424}, {'start': 22048, 'end': 81376}]
# Saved combined VAD segments for 1071.wav to VoxCeleb_gender\male_vad_results\1071_combined.wav
# Speech timestamps for 1072.wav: [{'start': 0, 'end': 79328}]
# Saved combined VAD segments for 1072.wav to VoxCeleb_gender\male_vad_results\1072_combined.wav
# Speech timestamps for 1073.wav: [{'start': 0, 'end': 70624}, {'start': 73248, 'end': 100832}, {'start': 112672, 'end': 122880}]
# Saved combined VAD segments for 1073.wav to VoxCeleb_gender\male_vad_results\1073_combined.wav
# Speech timestamps for 1074.wav: [{'start': 6176, 'end': 65536}]
# Saved combined VAD segments for 1074.wav to VoxCeleb_gender\male_vad_results\1074_combined.wav
# Speech timestamps for 1075.wav: [{'start': 0, 'end': 61408}, {'start': 65568, 'end': 97280}]
# Saved combined VAD segments for 1075.wav to VoxCeleb_gender\male_vad_results\1075_combined.wav
# Speech timestamps for 1076.wav: [{'start': 12320, 'end': 38880}]
# Saved combined VAD segments for 1076.wav to VoxCeleb_gender\male_vad_results\1076_combined.wav
# Speech timestamps for 1077.wav: [{'start': 5152, 'end': 63488}]
# Saved combined VAD segments for 1077.wav to VoxCeleb_gender\male_vad_results\1077_combined.wav
# Speech timestamps for 1078.wav: [{'start': 0, 'end': 120288}, {'start': 123424, 'end': 199680}]
# Saved combined VAD segments for 1078.wav to VoxCeleb_gender\male_vad_results\1078_combined.wav
# Speech timestamps for 1079.wav: [{'start': 0, 'end': 29152}, {'start': 36896, 'end': 71680}]
# Saved combined VAD segments for 1079.wav to VoxCeleb_gender\male_vad_results\1079_combined.wav
# Speech timestamps for 108.wav: [{'start': 544, 'end': 135168}]
# Saved combined VAD segments for 108.wav to VoxCeleb_gender\male_vad_results\108_combined.wav
# Speech timestamps for 1080.wav: [{'start': 0, 'end': 182272}]
# Saved combined VAD segments for 1080.wav to VoxCeleb_gender\male_vad_results\1080_combined.wav
# Speech timestamps for 1081.wav: [{'start': 2080, 'end': 123904}]
# Saved combined VAD segments for 1081.wav to VoxCeleb_gender\male_vad_results\1081_combined.wav
# Speech timestamps for 1082.wav: [{'start': 0, 'end': 24544}, {'start': 26656, 'end': 93184}]
# Saved combined VAD segments for 1082.wav to VoxCeleb_gender\male_vad_results\1082_combined.wav
# Speech timestamps for 1083.wav: [{'start': 0, 'end': 42976}, {'start': 48672, 'end': 68608}]
# Saved combined VAD segments for 1083.wav to VoxCeleb_gender\male_vad_results\1083_combined.wav
# Speech timestamps for 1084.wav: [{'start': 0, 'end': 4576}, {'start': 15392, 'end': 70656}]
# Saved combined VAD segments for 1084.wav to VoxCeleb_gender\male_vad_results\1084_combined.wav
# Speech timestamps for 1085.wav: [{'start': 0, 'end': 29152}, {'start': 33312, 'end': 61920}, {'start': 69664, 'end': 82944}]
# Saved combined VAD segments for 1085.wav to VoxCeleb_gender\male_vad_results\1085_combined.wav
# Speech timestamps for 1086.wav: [{'start': 0, 'end': 193536}]
# Saved combined VAD segments for 1086.wav to VoxCeleb_gender\male_vad_results\1086_combined.wav
# Speech timestamps for 1087.wav: [{'start': 2592, 'end': 83968}]
# Saved combined VAD segments for 1087.wav to VoxCeleb_gender\male_vad_results\1087_combined.wav
# Speech timestamps for 1088.wav: [{'start': 32, 'end': 12768}, {'start': 15392, 'end': 78848}]
# Saved combined VAD segments for 1088.wav to VoxCeleb_gender\male_vad_results\1088_combined.wav
# Speech timestamps for 1089.wav: [{'start': 9760, 'end': 27616}, {'start': 29728, 'end': 43488}, {'start': 51232, 'end': 60384}, {'start': 64032, 'end': 121856}]
# Saved combined VAD segments for 1089.wav to VoxCeleb_gender\male_vad_results\1089_combined.wav
# Speech timestamps for 109.wav: [{'start': 14368, 'end': 63488}]
# Saved combined VAD segments for 109.wav to VoxCeleb_gender\male_vad_results\109_combined.wav
# Speech timestamps for 1090.wav: [{'start': 4640, 'end': 82944}]
# Saved combined VAD segments for 1090.wav to VoxCeleb_gender\male_vad_results\1090_combined.wav
# Speech timestamps for 1091.wav: [{'start': 1568, 'end': 94208}]
# Saved combined VAD segments for 1091.wav to VoxCeleb_gender\male_vad_results\1091_combined.wav
# Speech timestamps for 1092.wav: [{'start': 0, 'end': 50656}, {'start': 57376, 'end': 67584}]
# Saved combined VAD segments for 1092.wav to VoxCeleb_gender\male_vad_results\1092_combined.wav
# Speech timestamps for 1093.wav: [{'start': 5152, 'end': 80864}, {'start': 85024, 'end': 116736}]
# Saved combined VAD segments for 1093.wav to VoxCeleb_gender\male_vad_results\1093_combined.wav
# Speech timestamps for 1094.wav: [{'start': 0, 'end': 28640}, {'start': 31264, 'end': 63488}]
# Saved combined VAD segments for 1094.wav to VoxCeleb_gender\male_vad_results\1094_combined.wav
# Speech timestamps for 1095.wav: [{'start': 544, 'end': 71648}]
# Saved combined VAD segments for 1095.wav to VoxCeleb_gender\male_vad_results\1095_combined.wav
# Speech timestamps for 1096.wav: [{'start': 7200, 'end': 56800}, {'start': 61472, 'end': 103904}, {'start': 107040, 'end': 163808}, {'start': 166432, 'end': 220128}]
# Saved combined VAD segments for 1096.wav to VoxCeleb_gender\male_vad_results\1096_combined.wav
# Speech timestamps for 1097.wav: [{'start': 4128, 'end': 48608}, {'start': 50720, 'end': 67584}]
# Saved combined VAD segments for 1097.wav to VoxCeleb_gender\male_vad_results\1097_combined.wav
# Speech timestamps for 1098.wav: [{'start': 3616, 'end': 24544}, {'start': 29216, 'end': 68608}]
# Saved combined VAD segments for 1098.wav to VoxCeleb_gender\male_vad_results\1098_combined.wav
# Speech timestamps for 1099.wav: [{'start': 0, 'end': 80896}]
# Saved combined VAD segments for 1099.wav to VoxCeleb_gender\male_vad_results\1099_combined.wav
# Speech timestamps for 11.wav: [{'start': 0, 'end': 68608}]
# Saved combined VAD segments for 11.wav to VoxCeleb_gender\male_vad_results\11_combined.wav
# Speech timestamps for 110.wav: [{'start': 5152, 'end': 46560}, {'start': 53280, 'end': 68608}]
# Saved combined VAD segments for 110.wav to VoxCeleb_gender\male_vad_results\110_combined.wav
# Speech timestamps for 1100.wav: [{'start': 0, 'end': 56800}, {'start': 58912, 'end': 70656}]
# Saved combined VAD segments for 1100.wav to VoxCeleb_gender\male_vad_results\1100_combined.wav
# Speech timestamps for 1101.wav: [{'start': 3616, 'end': 31712}, {'start': 33312, 'end': 95712}, {'start': 97824, 'end': 133600}, {'start': 135200, 'end': 195584}]
# Saved combined VAD segments for 1101.wav to VoxCeleb_gender\male_vad_results\1101_combined.wav
# Speech timestamps for 1102.wav: [{'start': 0, 'end': 111616}]
# Saved combined VAD segments for 1102.wav to VoxCeleb_gender\male_vad_results\1102_combined.wav
# Speech timestamps for 1103.wav: [{'start': 5664, 'end': 64512}]
# Saved combined VAD segments for 1103.wav to VoxCeleb_gender\male_vad_results\1103_combined.wav
# Speech timestamps for 1104.wav: [{'start': 0, 'end': 68608}]
# Saved combined VAD segments for 1104.wav to VoxCeleb_gender\male_vad_results\1104_combined.wav
# Speech timestamps for 1105.wav: [{'start': 1568, 'end': 50144}, {'start': 51744, 'end': 73696}, {'start': 78368, 'end': 92160}]
# Saved combined VAD segments for 1105.wav to VoxCeleb_gender\male_vad_results\1105_combined.wav
# Speech timestamps for 1106.wav: [{'start': 0, 'end': 82944}]
# Saved combined VAD segments for 1106.wav to VoxCeleb_gender\male_vad_results\1106_combined.wav
# Speech timestamps for 1107.wav: [{'start': 2080, 'end': 63456}, {'start': 65568, 'end': 136672}]
# Saved combined VAD segments for 1107.wav to VoxCeleb_gender\male_vad_results\1107_combined.wav
# Speech timestamps for 1108.wav: [{'start': 544, 'end': 97280}]
# Saved combined VAD segments for 1108.wav to VoxCeleb_gender\male_vad_results\1108_combined.wav
# Speech timestamps for 1109.wav: [{'start': 0, 'end': 74752}]
# Saved combined VAD segments for 1109.wav to VoxCeleb_gender\male_vad_results\1109_combined.wav
# Speech timestamps for 111.wav: [{'start': 2592, 'end': 211968}]
# Saved combined VAD segments for 111.wav to VoxCeleb_gender\male_vad_results\111_combined.wav
# Speech timestamps for 1110.wav: [{'start': 4640, 'end': 109536}]
# Saved combined VAD segments for 1110.wav to VoxCeleb_gender\male_vad_results\1110_combined.wav
# Speech timestamps for 1111.wav: [{'start': 0, 'end': 83968}]
# Saved combined VAD segments for 1111.wav to VoxCeleb_gender\male_vad_results\1111_combined.wav
# Speech timestamps for 1112.wav: [{'start': 0, 'end': 25056}, {'start': 30240, 'end': 72704}]
# Saved combined VAD segments for 1112.wav to VoxCeleb_gender\male_vad_results\1112_combined.wav
# Speech timestamps for 1113.wav: [{'start': 8736, 'end': 113632}, {'start': 115232, 'end': 124928}]
# Saved combined VAD segments for 1113.wav to VoxCeleb_gender\male_vad_results\1113_combined.wav
# Speech timestamps for 1114.wav: [{'start': 0, 'end': 152576}]
# Saved combined VAD segments for 1114.wav to VoxCeleb_gender\male_vad_results\1114_combined.wav
# Speech timestamps for 1115.wav: [{'start': 0, 'end': 82944}]
# Saved combined VAD segments for 1115.wav to VoxCeleb_gender\male_vad_results\1115_combined.wav
# Speech timestamps for 1116.wav: [{'start': 544, 'end': 7648}, {'start': 15392, 'end': 78848}]
# Saved combined VAD segments for 1116.wav to VoxCeleb_gender\male_vad_results\1116_combined.wav
# Speech timestamps for 1117.wav: [{'start': 0, 'end': 44512}, {'start': 50208, 'end': 94208}]
# Saved combined VAD segments for 1117.wav to VoxCeleb_gender\male_vad_results\1117_combined.wav
# Speech timestamps for 1118.wav: [{'start': 1568, 'end': 21472}, {'start': 23072, 'end': 53728}, {'start': 55840, 'end': 69632}]
# Saved combined VAD segments for 1118.wav to VoxCeleb_gender\male_vad_results\1118_combined.wav
# Speech timestamps for 1119.wav: [{'start': 0, 'end': 86016}]
# Saved combined VAD segments for 1119.wav to VoxCeleb_gender\male_vad_results\1119_combined.wav
# Speech timestamps for 112.wav: [{'start': 32, 'end': 65536}]
# Saved combined VAD segments for 112.wav to VoxCeleb_gender\male_vad_results\112_combined.wav
# Speech timestamps for 1120.wav: [{'start': 0, 'end': 70656}]
# Saved combined VAD segments for 1120.wav to VoxCeleb_gender\male_vad_results\1120_combined.wav
# Speech timestamps for 1121.wav: [{'start': 7200, 'end': 68608}]
# Saved combined VAD segments for 1121.wav to VoxCeleb_gender\male_vad_results\1121_combined.wav
# Speech timestamps for 1122.wav: [{'start': 544, 'end': 38368}, {'start': 40992, 'end': 66560}]
# Saved combined VAD segments for 1122.wav to VoxCeleb_gender\male_vad_results\1122_combined.wav
# Speech timestamps for 1123.wav: [{'start': 5664, 'end': 35808}, {'start': 42528, 'end': 91616}, {'start': 101408, 'end': 142336}]
# Saved combined VAD segments for 1123.wav to VoxCeleb_gender\male_vad_results\1123_combined.wav
# Speech timestamps for 1124.wav: [{'start': 0, 'end': 23008}, {'start': 26144, 'end': 61408}, {'start': 68640, 'end': 80896}]
# Saved combined VAD segments for 1124.wav to VoxCeleb_gender\male_vad_results\1124_combined.wav
# Speech timestamps for 1125.wav: [{'start': 32, 'end': 57312}, {'start': 60960, 'end': 72704}]
# Saved combined VAD segments for 1125.wav to VoxCeleb_gender\male_vad_results\1125_combined.wav
# Speech timestamps for 1126.wav: [{'start': 3616, 'end': 65536}]
# Saved combined VAD segments for 1126.wav to VoxCeleb_gender\male_vad_results\1126_combined.wav
# Speech timestamps for 1127.wav: [{'start': 0, 'end': 69632}]
# Saved combined VAD segments for 1127.wav to VoxCeleb_gender\male_vad_results\1127_combined.wav
# Speech timestamps for 1128.wav: [{'start': 0, 'end': 65536}]
# Saved combined VAD segments for 1128.wav to VoxCeleb_gender\male_vad_results\1128_combined.wav
# Speech timestamps for 1129.wav: [{'start': 0, 'end': 13792}, {'start': 16416, 'end': 63488}]
# Saved combined VAD segments for 1129.wav to VoxCeleb_gender\male_vad_results\1129_combined.wav
# Speech timestamps for 113.wav: [{'start': 32, 'end': 16864}, {'start': 21536, 'end': 126976}]
# Saved combined VAD segments for 113.wav to VoxCeleb_gender\male_vad_results\113_combined.wav
# Speech timestamps for 1130.wav: [{'start': 10272, 'end': 48608}, {'start': 53280, 'end': 66528}, {'start': 68640, 'end': 130528}, {'start': 132640, 'end': 144384}]
# Saved combined VAD segments for 1130.wav to VoxCeleb_gender\male_vad_results\1130_combined.wav
# Speech timestamps for 1131.wav: [{'start': 1056, 'end': 40416}, {'start': 46112, 'end': 110592}]
# Saved combined VAD segments for 1131.wav to VoxCeleb_gender\male_vad_results\1131_combined.wav
# Speech timestamps for 1132.wav: [{'start': 0, 'end': 22496}, {'start': 25632, 'end': 77824}]
# Saved combined VAD segments for 1132.wav to VoxCeleb_gender\male_vad_results\1132_combined.wav
# Speech timestamps for 1133.wav: [{'start': 2080, 'end': 82400}, {'start': 85024, 'end': 102400}]
# Saved combined VAD segments for 1133.wav to VoxCeleb_gender\male_vad_results\1133_combined.wav
# Speech timestamps for 1134.wav: [{'start': 5152, 'end': 23520}, {'start': 25120, 'end': 65536}]
# Saved combined VAD segments for 1134.wav to VoxCeleb_gender\male_vad_results\1134_combined.wav
# Speech timestamps for 1135.wav: [{'start': 4640, 'end': 63488}]
# Saved combined VAD segments for 1135.wav to VoxCeleb_gender\male_vad_results\1135_combined.wav
# Speech timestamps for 1136.wav: [{'start': 0, 'end': 13792}, {'start': 18976, 'end': 236512}, {'start': 238112, 'end': 321536}]
# Saved combined VAD segments for 1136.wav to VoxCeleb_gender\male_vad_results\1136_combined.wav
# Speech timestamps for 1137.wav: [{'start': 0, 'end': 19424}, {'start': 28704, 'end': 57824}, {'start': 60448, 'end': 77792}]
# Saved combined VAD segments for 1137.wav to VoxCeleb_gender\male_vad_results\1137_combined.wav
# Speech timestamps for 1138.wav: [{'start': 0, 'end': 66560}]
# Saved combined VAD segments for 1138.wav to VoxCeleb_gender\male_vad_results\1138_combined.wav
# Speech timestamps for 1139.wav: [{'start': 0, 'end': 67584}]
# Saved combined VAD segments for 1139.wav to VoxCeleb_gender\male_vad_results\1139_combined.wav
# Speech timestamps for 114.wav: [{'start': 32, 'end': 60384}]
# Saved combined VAD segments for 114.wav to VoxCeleb_gender\male_vad_results\114_combined.wav
# Speech timestamps for 1140.wav: [{'start': 2592, 'end': 20960}, {'start': 29216, 'end': 52704}, {'start': 56864, 'end': 73728}]
# Saved combined VAD segments for 1140.wav to VoxCeleb_gender\male_vad_results\1140_combined.wav
# Speech timestamps for 1141.wav: [{'start': 19488, 'end': 201728}]
# Saved combined VAD segments for 1141.wav to VoxCeleb_gender\male_vad_results\1141_combined.wav
# Speech timestamps for 1142.wav: [{'start': 32, 'end': 24032}, {'start': 28192, 'end': 82944}]
# Saved combined VAD segments for 1142.wav to VoxCeleb_gender\male_vad_results\1142_combined.wav
# Speech timestamps for 1143.wav: [{'start': 0, 'end': 89088}]
# Saved combined VAD segments for 1143.wav to VoxCeleb_gender\male_vad_results\1143_combined.wav
# Speech timestamps for 1144.wav: [{'start': 0, 'end': 5600}, {'start': 16928, 'end': 195584}]
# Saved combined VAD segments for 1144.wav to VoxCeleb_gender\male_vad_results\1144_combined.wav
# Speech timestamps for 1145.wav: [{'start': 544, 'end': 65536}]
# Saved combined VAD segments for 1145.wav to VoxCeleb_gender\male_vad_results\1145_combined.wav
# Speech timestamps for 1146.wav: [{'start': 0, 'end': 63488}]
# Saved combined VAD segments for 1146.wav to VoxCeleb_gender\male_vad_results\1146_combined.wav
# Speech timestamps for 1147.wav: [{'start': 1056, 'end': 50656}, {'start': 52256, 'end': 70656}]
# Saved combined VAD segments for 1147.wav to VoxCeleb_gender\male_vad_results\1147_combined.wav
# Speech timestamps for 1148.wav: [{'start': 0, 'end': 70656}]
# Saved combined VAD segments for 1148.wav to VoxCeleb_gender\male_vad_results\1148_combined.wav
# Speech timestamps for 1149.wav: [{'start': 2592, 'end': 46048}, {'start': 47648, 'end': 90112}]
# Saved combined VAD segments for 1149.wav to VoxCeleb_gender\male_vad_results\1149_combined.wav
# Speech timestamps for 115.wav: [{'start': 0, 'end': 34272}, {'start': 35872, 'end': 110592}]
# Saved combined VAD segments for 115.wav to VoxCeleb_gender\male_vad_results\115_combined.wav
# Speech timestamps for 1150.wav: [{'start': 7712, 'end': 114688}]
# Saved combined VAD segments for 1150.wav to VoxCeleb_gender\male_vad_results\1150_combined.wav
# Speech timestamps for 1151.wav: [{'start': 0, 'end': 81920}]
# Saved combined VAD segments for 1151.wav to VoxCeleb_gender\male_vad_results\1151_combined.wav
# Speech timestamps for 1152.wav: [{'start': 32, 'end': 63488}]
# Saved combined VAD segments for 1152.wav to VoxCeleb_gender\male_vad_results\1152_combined.wav
# Speech timestamps for 1153.wav: [{'start': 0, 'end': 5088}, {'start': 6688, 'end': 47072}, {'start': 52256, 'end': 68608}]
# Saved combined VAD segments for 1153.wav to VoxCeleb_gender\male_vad_results\1153_combined.wav
# Speech timestamps for 1154.wav: [{'start': 0, 'end': 45024}, {'start': 47648, 'end': 59872}, {'start': 62496, 'end': 93664}]
# Saved combined VAD segments for 1154.wav to VoxCeleb_gender\male_vad_results\1154_combined.wav
# Speech timestamps for 1155.wav: [{'start': 4128, 'end': 20960}, {'start': 25632, 'end': 73728}]
# Saved combined VAD segments for 1155.wav to VoxCeleb_gender\male_vad_results\1155_combined.wav
# Speech timestamps for 1156.wav: [{'start': 1568, 'end': 63488}]
# Saved combined VAD segments for 1156.wav to VoxCeleb_gender\male_vad_results\1156_combined.wav
# Speech timestamps for 1157.wav: [{'start': 4640, 'end': 68608}]
# Saved combined VAD segments for 1157.wav to VoxCeleb_gender\male_vad_results\1157_combined.wav
# Speech timestamps for 1158.wav: [{'start': 8736, 'end': 67584}]
# Saved combined VAD segments for 1158.wav to VoxCeleb_gender\male_vad_results\1158_combined.wav
# Speech timestamps for 1159.wav: [{'start': 0, 'end': 19936}, {'start': 24608, 'end': 65504}, {'start': 69664, 'end': 90112}]
# Saved combined VAD segments for 1159.wav to VoxCeleb_gender\male_vad_results\1159_combined.wav
# Speech timestamps for 116.wav: [{'start': 0, 'end': 144384}]
# Saved combined VAD segments for 116.wav to VoxCeleb_gender\male_vad_results\116_combined.wav
# Speech timestamps for 1160.wav: [{'start': 13344, 'end': 38880}, {'start': 46112, 'end': 157696}]
# Saved combined VAD segments for 1160.wav to VoxCeleb_gender\male_vad_results\1160_combined.wav
# Speech timestamps for 1161.wav: [{'start': 32, 'end': 46560}, {'start': 48160, 'end': 67584}]
# Saved combined VAD segments for 1161.wav to VoxCeleb_gender\male_vad_results\1161_combined.wav
# Speech timestamps for 1162.wav: [{'start': 0, 'end': 35808}, {'start': 37920, 'end': 87008}]
# Saved combined VAD segments for 1162.wav to VoxCeleb_gender\male_vad_results\1162_combined.wav
# Speech timestamps for 1163.wav: [{'start': 0, 'end': 13792}, {'start': 15392, 'end': 116192}, {'start': 122912, 'end': 167392}, {'start': 169504, 'end': 199136}, {'start': 201248, 'end': 231392}, {'start': 237600, 'end': 266720}, {'start': 268832, 'end': 293888}]
# Saved combined VAD segments for 1163.wav to VoxCeleb_gender\male_vad_results\1163_combined.wav
# Speech timestamps for 1164.wav: [{'start': 0, 'end': 37856}, {'start': 39968, 'end': 80896}]
# Saved combined VAD segments for 1164.wav to VoxCeleb_gender\male_vad_results\1164_combined.wav
# Speech timestamps for 1165.wav: [{'start': 0, 'end': 43488}, {'start': 47136, 'end': 96256}]
# Saved combined VAD segments for 1165.wav to VoxCeleb_gender\male_vad_results\1165_combined.wav
# Speech timestamps for 1166.wav: [{'start': 5152, 'end': 122880}]
# Saved combined VAD segments for 1166.wav to VoxCeleb_gender\male_vad_results\1166_combined.wav
# Speech timestamps for 1167.wav: [{'start': 0, 'end': 80896}]
# Saved combined VAD segments for 1167.wav to VoxCeleb_gender\male_vad_results\1167_combined.wav
# Speech timestamps for 1168.wav: [{'start': 1056, 'end': 39904}, {'start': 42528, 'end': 96256}]
# Saved combined VAD segments for 1168.wav to VoxCeleb_gender\male_vad_results\1168_combined.wav
# Speech timestamps for 1169.wav: [{'start': 32, 'end': 70656}]
# Saved combined VAD segments for 1169.wav to VoxCeleb_gender\male_vad_results\1169_combined.wav
# Speech timestamps for 117.wav: [{'start': 32, 'end': 51680}, {'start': 57888, 'end': 92160}]
# Saved combined VAD segments for 117.wav to VoxCeleb_gender\male_vad_results\117_combined.wav
# Speech timestamps for 1170.wav: [{'start': 4128, 'end': 72704}]
# Saved combined VAD segments for 1170.wav to VoxCeleb_gender\male_vad_results\1170_combined.wav
# Speech timestamps for 1171.wav: [{'start': 2592, 'end': 41952}, {'start': 44064, 'end': 68608}]
# Saved combined VAD segments for 1171.wav to VoxCeleb_gender\male_vad_results\1171_combined.wav
# Speech timestamps for 1172.wav: [{'start': 32, 'end': 15328}, {'start': 18464, 'end': 75776}]
# Saved combined VAD segments for 1172.wav to VoxCeleb_gender\male_vad_results\1172_combined.wav
# Speech timestamps for 1173.wav: [{'start': 2592, 'end': 41952}, {'start': 51232, 'end': 65536}]
# Saved combined VAD segments for 1173.wav to VoxCeleb_gender\male_vad_results\1173_combined.wav
# Speech timestamps for 1174.wav: [{'start': 0, 'end': 19936}, {'start': 24096, 'end': 70656}]
# Saved combined VAD segments for 1174.wav to VoxCeleb_gender\male_vad_results\1174_combined.wav
# Speech timestamps for 1175.wav: [{'start': 8224, 'end': 217088}]
# Saved combined VAD segments for 1175.wav to VoxCeleb_gender\male_vad_results\1175_combined.wav
# Speech timestamps for 1176.wav: [{'start': 3104, 'end': 64512}]
# Saved combined VAD segments for 1176.wav to VoxCeleb_gender\male_vad_results\1176_combined.wav
# Speech timestamps for 1177.wav: [{'start': 32, 'end': 60896}, {'start': 64544, 'end': 123904}]
# Saved combined VAD segments for 1177.wav to VoxCeleb_gender\male_vad_results\1177_combined.wav
# Speech timestamps for 1178.wav: [{'start': 32, 'end': 65536}]
# Saved combined VAD segments for 1178.wav to VoxCeleb_gender\male_vad_results\1178_combined.wav
# Speech timestamps for 1179.wav: [{'start': 1568, 'end': 7648}, {'start': 12832, 'end': 36832}, {'start': 41504, 'end': 64992}]
# Saved combined VAD segments for 1179.wav to VoxCeleb_gender\male_vad_results\1179_combined.wav
# Speech timestamps for 118.wav: [{'start': 544, 'end': 72704}]
# Saved combined VAD segments for 118.wav to VoxCeleb_gender\male_vad_results\118_combined.wav
# Speech timestamps for 1180.wav: [{'start': 1568, 'end': 43488}, {'start': 47136, 'end': 92128}]
# Saved combined VAD segments for 1180.wav to VoxCeleb_gender\male_vad_results\1180_combined.wav
# Speech timestamps for 1181.wav: [{'start': 0, 'end': 102400}]
# Saved combined VAD segments for 1181.wav to VoxCeleb_gender\male_vad_results\1181_combined.wav
# Speech timestamps for 1182.wav: [{'start': 0, 'end': 67584}]
# Saved combined VAD segments for 1182.wav to VoxCeleb_gender\male_vad_results\1182_combined.wav
# Speech timestamps for 1183.wav: [{'start': 2080, 'end': 44000}, {'start': 52256, 'end': 106496}]
# Saved combined VAD segments for 1183.wav to VoxCeleb_gender\male_vad_results\1183_combined.wav
# Speech timestamps for 1184.wav: [{'start': 2592, 'end': 104928}, {'start': 106528, 'end': 131072}]
# Saved combined VAD segments for 1184.wav to VoxCeleb_gender\male_vad_results\1184_combined.wav
# Speech timestamps for 1185.wav: [{'start': 32, 'end': 88064}]
# Saved combined VAD segments for 1185.wav to VoxCeleb_gender\male_vad_results\1185_combined.wav
# Speech timestamps for 1186.wav: [{'start': 3104, 'end': 17376}, {'start': 20000, 'end': 48608}, {'start': 53792, 'end': 111616}]
# Saved combined VAD segments for 1186.wav to VoxCeleb_gender\male_vad_results\1186_combined.wav
# Speech timestamps for 1187.wav: [{'start': 1568, 'end': 25568}, {'start': 31776, 'end': 70656}]
# Saved combined VAD segments for 1187.wav to VoxCeleb_gender\male_vad_results\1187_combined.wav
# Speech timestamps for 1188.wav: [{'start': 32, 'end': 70656}]
# Saved combined VAD segments for 1188.wav to VoxCeleb_gender\male_vad_results\1188_combined.wav
# Speech timestamps for 1189.wav: [{'start': 5664, 'end': 141312}]
# Saved combined VAD segments for 1189.wav to VoxCeleb_gender\male_vad_results\1189_combined.wav
# Speech timestamps for 119.wav: [{'start': 0, 'end': 165344}, {'start': 171040, 'end': 190464}]
# Saved combined VAD segments for 119.wav to VoxCeleb_gender\male_vad_results\119_combined.wav
# Speech timestamps for 1190.wav: [{'start': 0, 'end': 93184}]
# Saved combined VAD segments for 1190.wav to VoxCeleb_gender\male_vad_results\1190_combined.wav
# Speech timestamps for 1191.wav: [{'start': 0, 'end': 86016}]
# Saved combined VAD segments for 1191.wav to VoxCeleb_gender\male_vad_results\1191_combined.wav
# Speech timestamps for 1192.wav: [{'start': 0, 'end': 108544}]
# Saved combined VAD segments for 1192.wav to VoxCeleb_gender\male_vad_results\1192_combined.wav
# Speech timestamps for 1193.wav: [{'start': 3104, 'end': 39392}, {'start': 46624, 'end': 67584}]
# Saved combined VAD segments for 1193.wav to VoxCeleb_gender\male_vad_results\1193_combined.wav
# Speech timestamps for 1194.wav: [{'start': 544, 'end': 79872}]
# Saved combined VAD segments for 1194.wav to VoxCeleb_gender\male_vad_results\1194_combined.wav
# Speech timestamps for 1195.wav: [{'start': 0, 'end': 182272}]
# Saved combined VAD segments for 1195.wav to VoxCeleb_gender\male_vad_results\1195_combined.wav
# Speech timestamps for 1196.wav: [{'start': 0, 'end': 46560}, {'start': 50208, 'end': 121856}]
# Saved combined VAD segments for 1196.wav to VoxCeleb_gender\male_vad_results\1196_combined.wav
# Speech timestamps for 1197.wav: [{'start': 32, 'end': 91104}, {'start': 92704, 'end': 198624}, {'start': 200224, 'end': 246240}, {'start': 247840, 'end': 254944}, {'start': 268832, 'end': 293888}]
# Saved combined VAD segments for 1197.wav to VoxCeleb_gender\male_vad_results\1197_combined.wav
# Speech timestamps for 1198.wav: [{'start': 1056, 'end': 80896}]
# Saved combined VAD segments for 1198.wav to VoxCeleb_gender\male_vad_results\1198_combined.wav
# Speech timestamps for 1199.wav: [{'start': 5152, 'end': 20960}, {'start': 28704, 'end': 57824}, {'start': 59936, 'end': 73728}]
# Saved combined VAD segments for 1199.wav to VoxCeleb_gender\male_vad_results\1199_combined.wav
# Speech timestamps for 12.wav: [{'start': 32, 'end': 46560}, {'start': 52256, 'end': 99328}]
# Saved combined VAD segments for 12.wav to VoxCeleb_gender\male_vad_results\12_combined.wav
# Speech timestamps for 120.wav: [{'start': 0, 'end': 74752}]
# Saved combined VAD segments for 120.wav to VoxCeleb_gender\male_vad_results\120_combined.wav
# Speech timestamps for 1200.wav: [{'start': 32, 'end': 51168}, {'start': 53280, 'end': 77824}]
# Saved combined VAD segments for 1200.wav to VoxCeleb_gender\male_vad_results\1200_combined.wav
# Speech timestamps for 1201.wav: [{'start': 2592, 'end': 67584}]
# Saved combined VAD segments for 1201.wav to VoxCeleb_gender\male_vad_results\1201_combined.wav
# Speech timestamps for 1202.wav: [{'start': 0, 'end': 68608}]
# Saved combined VAD segments for 1202.wav to VoxCeleb_gender\male_vad_results\1202_combined.wav
# Speech timestamps for 1203.wav: [{'start': 0, 'end': 73728}]
# Saved combined VAD segments for 1203.wav to VoxCeleb_gender\male_vad_results\1203_combined.wav
# Speech timestamps for 1204.wav: [{'start': 0, 'end': 23008}, {'start': 28192, 'end': 72704}]
# Saved combined VAD segments for 1204.wav to VoxCeleb_gender\male_vad_results\1204_combined.wav
# Speech timestamps for 1205.wav: [{'start': 1056, 'end': 19424}, {'start': 23072, 'end': 74752}]
# Saved combined VAD segments for 1205.wav to VoxCeleb_gender\male_vad_results\1205_combined.wav
# Speech timestamps for 1206.wav: [{'start': 2592, 'end': 45536}, {'start': 54304, 'end': 63488}]
# Saved combined VAD segments for 1206.wav to VoxCeleb_gender\male_vad_results\1206_combined.wav
# Speech timestamps for 1207.wav: [{'start': 0, 'end': 84448}, {'start': 86560, 'end': 114688}]
# Saved combined VAD segments for 1207.wav to VoxCeleb_gender\male_vad_results\1207_combined.wav
# Speech timestamps for 1208.wav: [{'start': 9760, 'end': 81920}]
# Saved combined VAD segments for 1208.wav to VoxCeleb_gender\male_vad_results\1208_combined.wav
# Speech timestamps for 1209.wav: [{'start': 8736, 'end': 150496}, {'start': 152608, 'end': 203776}]
# Saved combined VAD segments for 1209.wav to VoxCeleb_gender\male_vad_results\1209_combined.wav
# Speech timestamps for 121.wav: [{'start': 0, 'end': 72704}]
# Saved combined VAD segments for 121.wav to VoxCeleb_gender\male_vad_results\121_combined.wav
# Speech timestamps for 1210.wav: [{'start': 2592, 'end': 50656}, {'start': 53792, 'end': 95232}]
# Saved combined VAD segments for 1210.wav to VoxCeleb_gender\male_vad_results\1210_combined.wav
# Speech timestamps for 1211.wav: [{'start': 3616, 'end': 59872}, {'start': 64544, 'end': 87008}, {'start': 90656, 'end': 113664}]
# Saved combined VAD segments for 1211.wav to VoxCeleb_gender\male_vad_results\1211_combined.wav
# Speech timestamps for 1212.wav: [{'start': 5664, 'end': 36320}, {'start': 40992, 'end': 58336}, {'start': 63008, 'end': 98272}, {'start': 100896, 'end': 137216}]
# Saved combined VAD segments for 1212.wav to VoxCeleb_gender\male_vad_results\1212_combined.wav
# Speech timestamps for 1213.wav: [{'start': 7200, 'end': 15840}, {'start': 19488, 'end': 33760}, {'start': 38944, 'end': 84448}]
# Saved combined VAD segments for 1213.wav to VoxCeleb_gender\male_vad_results\1213_combined.wav
# Speech timestamps for 1214.wav: [{'start': 0, 'end': 69632}]
# Saved combined VAD segments for 1214.wav to VoxCeleb_gender\male_vad_results\1214_combined.wav
# Speech timestamps for 1215.wav: [{'start': 32, 'end': 62432}]
# Saved combined VAD segments for 1215.wav to VoxCeleb_gender\male_vad_results\1215_combined.wav
# Speech timestamps for 1216.wav: [{'start': 1056, 'end': 68608}]
# Saved combined VAD segments for 1216.wav to VoxCeleb_gender\male_vad_results\1216_combined.wav
# Speech timestamps for 1217.wav: [{'start': 32, 'end': 9696}, {'start': 15392, 'end': 67584}]
# Saved combined VAD segments for 1217.wav to VoxCeleb_gender\male_vad_results\1217_combined.wav
# Speech timestamps for 1218.wav: [{'start': 1056, 'end': 95200}, {'start': 96800, 'end': 114688}]
# Saved combined VAD segments for 1218.wav to VoxCeleb_gender\male_vad_results\1218_combined.wav
# Speech timestamps for 1219.wav: [{'start': 0, 'end': 65536}]
# Saved combined VAD segments for 1219.wav to VoxCeleb_gender\male_vad_results\1219_combined.wav
# Speech timestamps for 122.wav: [{'start': 2080, 'end': 38368}, {'start': 41504, 'end': 73728}]
# Saved combined VAD segments for 122.wav to VoxCeleb_gender\male_vad_results\122_combined.wav
# Speech timestamps for 1220.wav: [{'start': 0, 'end': 91136}]
# Saved combined VAD segments for 1220.wav to VoxCeleb_gender\male_vad_results\1220_combined.wav
# Speech timestamps for 1221.wav: [{'start': 0, 'end': 90112}]
# Saved combined VAD segments for 1221.wav to VoxCeleb_gender\male_vad_results\1221_combined.wav
# Speech timestamps for 1222.wav: [{'start': 1056, 'end': 30176}, {'start': 33824, 'end': 52704}, {'start': 54304, 'end': 113664}]
# Saved combined VAD segments for 1222.wav to VoxCeleb_gender\male_vad_results\1222_combined.wav
# Speech timestamps for 1223.wav: [{'start': 6688, 'end': 11744}, {'start': 13856, 'end': 75776}]
# Saved combined VAD segments for 1223.wav to VoxCeleb_gender\male_vad_results\1223_combined.wav
# Speech timestamps for 1224.wav: [{'start': 1056, 'end': 60896}, {'start': 66592, 'end': 97248}, {'start': 98848, 'end': 218592}, {'start': 220192, 'end': 301024}, {'start': 303648, 'end': 434656}, {'start': 438304, 'end': 462848}]
# Saved combined VAD segments for 1224.wav to VoxCeleb_gender\male_vad_results\1224_combined.wav
# Speech timestamps for 1225.wav: [{'start': 3616, 'end': 10208}, {'start': 13344, 'end': 101376}]
# Saved combined VAD segments for 1225.wav to VoxCeleb_gender\male_vad_results\1225_combined.wav
# Speech timestamps for 1226.wav: [{'start': 0, 'end': 24032}, {'start': 26144, 'end': 96256}]
# Saved combined VAD segments for 1226.wav to VoxCeleb_gender\male_vad_results\1226_combined.wav
# Speech timestamps for 1227.wav: [{'start': 0, 'end': 152576}]
# Saved combined VAD segments for 1227.wav to VoxCeleb_gender\male_vad_results\1227_combined.wav
# Speech timestamps for 1228.wav: [{'start': 3104, 'end': 66528}, {'start': 70176, 'end': 110592}]
# Saved combined VAD segments for 1228.wav to VoxCeleb_gender\male_vad_results\1228_combined.wav
# Speech timestamps for 1229.wav: [{'start': 0, 'end': 5600}, {'start': 7712, 'end': 47072}, {'start': 48672, 'end': 95712}, {'start': 99360, 'end': 157696}]
# Saved combined VAD segments for 1229.wav to VoxCeleb_gender\male_vad_results\1229_combined.wav
# Speech timestamps for 123.wav: [{'start': 8224, 'end': 15328}, {'start': 24096, 'end': 37856}, {'start': 40480, 'end': 66560}]
# Saved combined VAD segments for 123.wav to VoxCeleb_gender\male_vad_results\123_combined.wav
# Speech timestamps for 1230.wav: [{'start': 0, 'end': 28128}, {'start': 29728, 'end': 75232}, {'start': 79392, 'end': 97280}]
# Saved combined VAD segments for 1230.wav to VoxCeleb_gender\male_vad_results\1230_combined.wav
# Speech timestamps for 1231.wav: [{'start': 32, 'end': 20448}, {'start': 22048, 'end': 74752}]
# Saved combined VAD segments for 1231.wav to VoxCeleb_gender\male_vad_results\1231_combined.wav
# ...
# Saved combined VAD segments for 92.wav to VoxCeleb_gender\female_vad_results\92_combined.wav
# Speech timestamps for 920.wav: [{'start': 6688, 'end': 86016}]
# Saved combined VAD segments for 920.wav to VoxCeleb_gender\female_vad_results\920_combined.wav
# Speech timestamps for 921.wav: [{'start': 5664, 'end': 80896}]
# Saved combined VAD segments for 921.wav to VoxCeleb_gender\female_vad_results\921_combined.wav
# Speech timestamps for 922.wav: [{'start': 0, 'end': 50656}, {'start': 54816, 'end': 175104}]
# Saved combined VAD segments for 922.wav to VoxCeleb_gender\female_vad_results\922_combined.wav
# Speech timestamps for 923.wav: [{'start': 32, 'end': 54752}, {'start': 57888, 'end': 80896}]
# Saved combined VAD segments for 923.wav to VoxCeleb_gender\female_vad_results\923_combined.wav
# Speech timestamps for 924.wav: [{'start': 8736, 'end': 61408}]
# Saved combined VAD segments for 924.wav to VoxCeleb_gender\female_vad_results\924_combined.wav
# Speech timestamps for 925.wav: [{'start': 32, 'end': 80896}]
# Saved combined VAD segments for 925.wav to VoxCeleb_gender\female_vad_results\925_combined.wav
# Speech timestamps for 926.wav: [{'start': 0, 'end': 158720}]
# Saved combined VAD segments for 926.wav to VoxCeleb_gender\female_vad_results\926_combined.wav
# Speech timestamps for 927.wav: [{'start': 7200, 'end': 56288}, {'start': 63008, 'end': 75232}, {'start': 85536, 'end': 141312}]
# Saved combined VAD segments for 927.wav to VoxCeleb_gender\female_vad_results\927_combined.wav
# Speech timestamps for 928.wav: [{'start': 32, 'end': 77824}]
# Saved combined VAD segments for 928.wav to VoxCeleb_gender\female_vad_results\928_combined.wav
# Speech timestamps for 929.wav: [{'start': 2080, 'end': 132096}]
# Saved combined VAD segments for 929.wav to VoxCeleb_gender\female_vad_results\929_combined.wav
# Speech timestamps for 93.wav: [{'start': 5152, 'end': 29152}, {'start': 33312, 'end': 65536}]
# Saved combined VAD segments for 93.wav to VoxCeleb_gender\female_vad_results\93_combined.wav
# Speech timestamps for 930.wav: [{'start': 4128, 'end': 67584}]
# Saved combined VAD segments for 930.wav to VoxCeleb_gender\female_vad_results\930_combined.wav
# Speech timestamps for 931.wav: [{'start': 8224, 'end': 58848}, {'start': 60448, 'end': 170464}, {'start': 173088, 'end': 199136}, {'start': 202272, 'end': 233952}, {'start': 235552, 'end': 268288}]
# Saved combined VAD segments for 931.wav to VoxCeleb_gender\female_vad_results\931_combined.wav
# Speech timestamps for 932.wav: [{'start': 0, 'end': 68608}]
# Saved combined VAD segments for 932.wav to VoxCeleb_gender\female_vad_results\932_combined.wav
# Speech timestamps for 933.wav: [{'start': 0, 'end': 114656}, {'start': 118816, 'end': 182272}]
# Saved combined VAD segments for 933.wav to VoxCeleb_gender\female_vad_results\933_combined.wav
# Speech timestamps for 934.wav: [{'start': 1568, 'end': 70656}]
# Saved combined VAD segments for 934.wav to VoxCeleb_gender\female_vad_results\934_combined.wav
# Speech timestamps for 935.wav: [{'start': 0, 'end': 130048}]
# Saved combined VAD segments for 935.wav to VoxCeleb_gender\female_vad_results\935_combined.wav
# Speech timestamps for 936.wav: [{'start': 2080, 'end': 161760}, {'start': 163872, 'end': 283648}]
# Saved combined VAD segments for 936.wav to VoxCeleb_gender\female_vad_results\936_combined.wav
# Speech timestamps for 937.wav: [{'start': 0, 'end': 183776}, {'start': 185888, 'end': 297984}]
# Saved combined VAD segments for 937.wav to VoxCeleb_gender\female_vad_results\937_combined.wav
# Speech timestamps for 938.wav: [{'start': 32, 'end': 15840}, {'start': 20512, 'end': 68608}]
# Saved combined VAD segments for 938.wav to VoxCeleb_gender\female_vad_results\938_combined.wav
# Speech timestamps for 939.wav: [{'start': 9248, 'end': 65536}]
# Saved combined VAD segments for 939.wav to VoxCeleb_gender\female_vad_results\939_combined.wav
# Speech timestamps for 94.wav: [{'start': 2080, 'end': 36832}, {'start': 43040, 'end': 58848}, {'start': 61472, 'end': 88064}]
# Saved combined VAD segments for 94.wav to VoxCeleb_gender\female_vad_results\94_combined.wav
# Speech timestamps for 940.wav: [{'start': 1568, 'end': 167936}]
# Saved combined VAD segments for 940.wav to VoxCeleb_gender\female_vad_results\940_combined.wav
# Speech timestamps for 941.wav: [{'start': 0, 'end': 120832}]
# Saved combined VAD segments for 941.wav to VoxCeleb_gender\female_vad_results\941_combined.wav
# Speech timestamps for 942.wav: [{'start': 0, 'end': 80896}]
# Saved combined VAD segments for 942.wav to VoxCeleb_gender\female_vad_results\942_combined.wav
# Speech timestamps for 943.wav: [{'start': 0, 'end': 42464}, {'start': 45088, 'end': 88064}]
# Saved combined VAD segments for 943.wav to VoxCeleb_gender\female_vad_results\943_combined.wav
# Speech timestamps for 944.wav: [{'start': 1056, 'end': 30688}, {'start': 38944, 'end': 73728}]
# Saved combined VAD segments for 944.wav to VoxCeleb_gender\female_vad_results\944_combined.wav
# Speech timestamps for 945.wav: [{'start': 1056, 'end': 25056}, {'start': 27680, 'end': 70656}]
# Saved combined VAD segments for 945.wav to VoxCeleb_gender\female_vad_results\945_combined.wav
# Speech timestamps for 946.wav: [{'start': 10784, 'end': 197632}]
# Saved combined VAD segments for 946.wav to VoxCeleb_gender\female_vad_results\946_combined.wav
# Speech timestamps for 947.wav: [{'start': 4128, 'end': 152576}]
# Saved combined VAD segments for 947.wav to VoxCeleb_gender\female_vad_results\947_combined.wav
# Speech timestamps for 948.wav: [{'start': 544, 'end': 93184}]
# Saved combined VAD segments for 948.wav to VoxCeleb_gender\female_vad_results\948_combined.wav
# Speech timestamps for 949.wav: [{'start': 2080, 'end': 27104}, {'start': 29216, 'end': 42464}, {'start': 45088, 'end': 68064}, {'start': 69664, 'end': 180192}, {'start': 181792, 'end': 238592}]
# Saved combined VAD segments for 949.wav to VoxCeleb_gender\female_vad_results\949_combined.wav
# Speech timestamps for 95.wav: [{'start': 0, 'end': 12768}, {'start': 20000, 'end': 34272}, {'start': 35872, 'end': 78848}]
# Saved combined VAD segments for 95.wav to VoxCeleb_gender\female_vad_results\95_combined.wav
# Speech timestamps for 950.wav: [{'start': 0, 'end': 95232}]
# Saved combined VAD segments for 950.wav to VoxCeleb_gender\female_vad_results\950_combined.wav
# Speech timestamps for 951.wav: [{'start': 1568, 'end': 118240}, {'start': 119840, 'end': 161248}, {'start': 167968, 'end': 309248}]
# Saved combined VAD segments for 951.wav to VoxCeleb_gender\female_vad_results\951_combined.wav
# Speech timestamps for 952.wav: [{'start': 1056, 'end': 67552}]
# Saved combined VAD segments for 952.wav to VoxCeleb_gender\female_vad_results\952_combined.wav
# Speech timestamps for 953.wav: [{'start': 1568, 'end': 111616}]
# Saved combined VAD segments for 953.wav to VoxCeleb_gender\female_vad_results\953_combined.wav
# Speech timestamps for 954.wav: [{'start': 0, 'end': 66016}, {'start': 70688, 'end': 127968}, {'start': 131616, 'end': 147456}]
# Saved combined VAD segments for 954.wav to VoxCeleb_gender\female_vad_results\954_combined.wav
# Speech timestamps for 955.wav: [{'start': 6176, 'end': 11232}, {'start': 22048, 'end': 29152}]
# Saved combined VAD segments for 955.wav to VoxCeleb_gender\female_vad_results\955_combined.wav
# Speech timestamps for 956.wav: [{'start': 1056, 'end': 15328}, {'start': 17952, 'end': 198656}]
# Saved combined VAD segments for 956.wav to VoxCeleb_gender\female_vad_results\956_combined.wav
# Speech timestamps for 957.wav: [{'start': 32, 'end': 129024}]
# Saved combined VAD segments for 957.wav to VoxCeleb_gender\female_vad_results\957_combined.wav
# Speech timestamps for 958.wav: [{'start': 5152, 'end': 83968}]
# Saved combined VAD segments for 958.wav to VoxCeleb_gender\female_vad_results\958_combined.wav
# Speech timestamps for 959.wav: [{'start': 544, 'end': 36320}, {'start': 40480, 'end': 56288}, {'start': 57888, 'end': 104448}]
# Saved combined VAD segments for 959.wav to VoxCeleb_gender\female_vad_results\959_combined.wav
# Speech timestamps for 96.wav: [{'start': 4128, 'end': 49120}, {'start': 50720, 'end': 88064}]
# Saved combined VAD segments for 96.wav to VoxCeleb_gender\female_vad_results\96_combined.wav
# Speech timestamps for 960.wav: [{'start': 0, 'end': 18400}, {'start': 23072, 'end': 42976}, {'start': 46624, 'end': 65536}]
# Saved combined VAD segments for 960.wav to VoxCeleb_gender\female_vad_results\960_combined.wav
# Speech timestamps for 961.wav: [{'start': 0, 'end': 92160}]
# Saved combined VAD segments for 961.wav to VoxCeleb_gender\female_vad_results\961_combined.wav
# Speech timestamps for 962.wav: [{'start': 9248, 'end': 65536}]
# Saved combined VAD segments for 962.wav to VoxCeleb_gender\female_vad_results\962_combined.wav
# Speech timestamps for 963.wav: [{'start': 4128, 'end': 114656}, {'start': 121376, 'end': 157696}]
# Saved combined VAD segments for 963.wav to VoxCeleb_gender\female_vad_results\963_combined.wav
# Speech timestamps for 964.wav: [{'start': 0, 'end': 173056}]
# Saved combined VAD segments for 964.wav to VoxCeleb_gender\female_vad_results\964_combined.wav
# Speech timestamps for 965.wav: [{'start': 1056, 'end': 91136}]
# Saved combined VAD segments for 965.wav to VoxCeleb_gender\female_vad_results\965_combined.wav
# Speech timestamps for 966.wav: [{'start': 32, 'end': 78848}]
# Saved combined VAD segments for 966.wav to VoxCeleb_gender\female_vad_results\966_combined.wav
# Speech timestamps for 967.wav: [{'start': 544, 'end': 61408}, {'start': 63008, 'end': 78848}]
# Saved combined VAD segments for 967.wav to VoxCeleb_gender\female_vad_results\967_combined.wav
# Speech timestamps for 968.wav: [{'start': 1568, 'end': 66528}, {'start': 68128, 'end': 88064}]
# Saved combined VAD segments for 968.wav to VoxCeleb_gender\female_vad_results\968_combined.wav
# Speech timestamps for 969.wav: [{'start': 0, 'end': 105472}]
# Saved combined VAD segments for 969.wav to VoxCeleb_gender\female_vad_results\969_combined.wav
# Speech timestamps for 97.wav: [{'start': 4640, 'end': 82912}, {'start': 85536, 'end': 177152}]
# Saved combined VAD segments for 97.wav to VoxCeleb_gender\female_vad_results\97_combined.wav
# Speech timestamps for 970.wav: [{'start': 0, 'end': 89088}]
# Saved combined VAD segments for 970.wav to VoxCeleb_gender\female_vad_results\970_combined.wav
# Speech timestamps for 971.wav: [{'start': 2592, 'end': 72672}, {'start': 74784, 'end': 124384}, {'start': 128032, 'end': 175104}]
# Saved combined VAD segments for 971.wav to VoxCeleb_gender\female_vad_results\971_combined.wav
# Speech timestamps for 972.wav: [{'start': 0, 'end': 5600}, {'start': 10272, 'end': 88544}, {'start': 92704, 'end': 136160}]
# Saved combined VAD segments for 972.wav to VoxCeleb_gender\female_vad_results\972_combined.wav
# Speech timestamps for 973.wav: [{'start': 0, 'end': 64480}, {'start': 66080, 'end': 72704}]
# Saved combined VAD segments for 973.wav to VoxCeleb_gender\female_vad_results\973_combined.wav
# Speech timestamps for 974.wav: [{'start': 0, 'end': 5088}, {'start': 11808, 'end': 38368}, {'start': 41504, 'end': 63488}]
# Saved combined VAD segments for 974.wav to VoxCeleb_gender\female_vad_results\974_combined.wav
# Speech timestamps for 975.wav: [{'start': 0, 'end': 135168}]
# Saved combined VAD segments for 975.wav to VoxCeleb_gender\female_vad_results\975_combined.wav
# Speech timestamps for 976.wav: [{'start': 3104, 'end': 27104}, {'start': 32288, 'end': 47072}, {'start': 59424, 'end': 123904}]
# Saved combined VAD segments for 976.wav to VoxCeleb_gender\female_vad_results\976_combined.wav
# Speech timestamps for 977.wav: [{'start': 32, 'end': 10720}, {'start': 20000, 'end': 103424}]
# Saved combined VAD segments for 977.wav to VoxCeleb_gender\female_vad_results\977_combined.wav
# Speech timestamps for 978.wav: [{'start': 8224, 'end': 152576}]
# Saved combined VAD segments for 978.wav to VoxCeleb_gender\female_vad_results\978_combined.wav
# Speech timestamps for 979.wav: [{'start': 13344, 'end': 21984}, {'start': 28704, 'end': 42976}, {'start': 57888, 'end': 116736}]
# Saved combined VAD segments for 979.wav to VoxCeleb_gender\female_vad_results\979_combined.wav
# Speech timestamps for 98.wav: [{'start': 3616, 'end': 79840}, {'start': 81952, 'end': 90112}]
# Saved combined VAD segments for 98.wav to VoxCeleb_gender\female_vad_results\98_combined.wav
# Speech timestamps for 980.wav: [{'start': 32, 'end': 115712}]
# Saved combined VAD segments for 980.wav to VoxCeleb_gender\female_vad_results\980_combined.wav
# Speech timestamps for 981.wav: [{'start': 0, 'end': 68608}]
# Saved combined VAD segments for 981.wav to VoxCeleb_gender\female_vad_results\981_combined.wav
# Speech timestamps for 982.wav: [{'start': 1056, 'end': 200704}]
# Saved combined VAD segments for 982.wav to VoxCeleb_gender\female_vad_results\982_combined.wav
# Speech timestamps for 983.wav: [{'start': 0, 'end': 92640}, {'start': 94752, 'end': 125920}, {'start': 128032, 'end': 165888}]
# Saved combined VAD segments for 983.wav to VoxCeleb_gender\female_vad_results\983_combined.wav
# Speech timestamps for 984.wav: [{'start': 544, 'end': 23008}, {'start': 24608, 'end': 72704}]
# Saved combined VAD segments for 984.wav to VoxCeleb_gender\female_vad_results\984_combined.wav
# Speech timestamps for 985.wav: [{'start': 544, 'end': 19936}, {'start': 21536, 'end': 82944}]
# Saved combined VAD segments for 985.wav to VoxCeleb_gender\female_vad_results\985_combined.wav
# Speech timestamps for 986.wav: [{'start': 0, 'end': 38880}, {'start': 40480, 'end': 67552}, {'start': 70176, 'end': 107520}]
# Saved combined VAD segments for 986.wav to VoxCeleb_gender\female_vad_results\986_combined.wav
# Speech timestamps for 987.wav: [{'start': 0, 'end': 37856}, {'start': 39968, 'end': 72160}, {'start': 74272, 'end': 150528}]
# Saved combined VAD segments for 987.wav to VoxCeleb_gender\female_vad_results\987_combined.wav
# Speech timestamps for 988.wav: [{'start': 0, 'end': 50656}, {'start': 54816, 'end': 103424}]
# Saved combined VAD segments for 988.wav to VoxCeleb_gender\female_vad_results\988_combined.wav
# Speech timestamps for 989.wav: [{'start': 1056, 'end': 80896}]
# Saved combined VAD segments for 989.wav to VoxCeleb_gender\female_vad_results\989_combined.wav
# Speech timestamps for 99.wav: [{'start': 544, 'end': 67552}, {'start': 70176, 'end': 155648}]
# Saved combined VAD segments for 99.wav to VoxCeleb_gender\female_vad_results\99_combined.wav
# Speech timestamps for 990.wav: [{'start': 0, 'end': 68608}]
# Saved combined VAD segments for 990.wav to VoxCeleb_gender\female_vad_results\990_combined.wav
# Speech timestamps for 991.wav: [{'start': 6688, 'end': 47072}, {'start': 49184, 'end': 63968}, {'start': 68640, 'end': 91616}, {'start': 93216, 'end': 126944}, {'start': 128544, 'end': 139264}]
# Saved combined VAD segments for 991.wav to VoxCeleb_gender\female_vad_results\991_combined.wav
# Speech timestamps for 992.wav: [{'start': 32, 'end': 88064}]
# Saved combined VAD segments for 992.wav to VoxCeleb_gender\female_vad_results\992_combined.wav
# Speech timestamps for 993.wav: [{'start': 15392, 'end': 96256}]
# Saved combined VAD segments for 993.wav to VoxCeleb_gender\female_vad_results\993_combined.wav
# Speech timestamps for 994.wav: [{'start': 4128, 'end': 103424}]
# Saved combined VAD segments for 994.wav to VoxCeleb_gender\female_vad_results\994_combined.wav
# Speech timestamps for 995.wav: [{'start': 544, 'end': 37856}, {'start': 39456, 'end': 69632}]
# Saved combined VAD segments for 995.wav to VoxCeleb_gender\female_vad_results\995_combined.wav
# Speech timestamps for 996.wav: [{'start': 17440, 'end': 75776}]
# Saved combined VAD segments for 996.wav to VoxCeleb_gender\female_vad_results\996_combined.wav
# Speech timestamps for 997.wav: [{'start': 32, 'end': 63488}]
# Saved combined VAD segments for 997.wav to VoxCeleb_gender\female_vad_results\997_combined.wav
# Speech timestamps for 998.wav: [{'start': 10272, 'end': 79328}, {'start': 81440, 'end': 96256}]
# Saved combined VAD segments for 998.wav to VoxCeleb_gender\female_vad_results\998_combined.wav
# Speech timestamps for 999.wav: [{'start': 4128, 'end': 90112}]
# Saved combined VAD segments for 999.wav to VoxCeleb_gender\female_vad_results\999_combined.wav

# %%
male_folder = os.path.join(root_folder, "male_vad_results")
female_folder = os.path.join(root_folder, "female_vad_results")

average_length_male = calculate_average_length(male_folder)
average_length_female = calculate_average_length(female_folder)

print(f"Average audio length for male files: {average_length_male:.2f} seconds")
print(f"Average audio length for female files: {average_length_female:.2f} seconds")
# Out:
# Average audio length for male files: 6.53 seconds
# Average audio length for female files: 6.82 seconds

# %% [markdown]
# ## 3. processing the Audio Files

# %%
def process_audio(input_folder, output_folder, target_db=-30, target_duration=6):
    os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist

    for audio_file in os.listdir(input_folder):
        if audio_file.endswith((".wav")): 
            file_path = os.path.join(input_folder, audio_file)

            audio, sr = librosa.load(file_path, sr=None)

            # Log original audio length
            original_length = len(audio) / sr

            reduced_noise_audio = nr.reduce_noise(y=audio, sr=sr)

            # Check if noise reduction changes audio length
            if len(reduced_noise_audio) == 0:
                continue  # Skip if no audio after noise reduction

            # Normalize audio to target dB level
            audio_db = librosa.amplitude_to_db(reduced_noise_audio)
            normalization_factor = target_db - audio_db.mean()
            normalized_audio = reduced_noise_audio * (10 ** (normalization_factor / 20))

            target_samples = int(target_duration * sr)

            # Adjust audio length to target duration
            if len(normalized_audio) > target_samples:
                # Trim audio if it's longer than target duration
                adjusted_audio = normalized_audio[:target_samples]
            else:
                # Pad audio if it's shorter than target duration
                adjusted_audio = np.pad(normalized_audio, (0, target_samples - len(normalized_audio)), mode='constant')

            # Ensure the adjusted audio is exactly the target duration
            adjusted_audio = adjusted_audio[:target_samples]  # Trim again just to be safe

            output_file_path = os.path.join(output_folder, audio_file)
            sf.write(output_file_path, adjusted_audio, sr)

# %%
output_male_folder = 'VoxCeleb_gender/Final Data/males'
output_female_folder = 'VoxCeleb_gender/Final Data/females'

os.makedirs(output_male_folder, exist_ok=True)
os.makedirs(output_female_folder, exist_ok=True)

process_audio(male_folder, output_male_folder)
process_audio(female_folder, output_female_folder)

# %% [markdown]
# ## 4. Data Augmentation

# %%
def pitch_shift(audio_file, n_steps):
    y, sr = librosa.load(audio_file)
    y_shifted = librosa.effects.pitch_shift(y, sr=sr, n_steps=n_steps)  
    sf.write(audio_file.replace('.wav', f'_pitch_shift_{n_steps}.wav'), y_shifted, sr)

# %%
def time_stretch(audio_file, rate):
    y, sr = librosa.load(audio_file)
    y_stretched = librosa.effects.time_stretch(y, rate=rate)  
    sf.write(audio_file.replace('.wav', f'_time_stretch_{rate}.wav'), y_stretched, sr)

# %%
def process_directory(root_dir):
    for subdir, dirs, files in os.walk(root_dir):
        for file in files:
            if file.endswith('.wav'):
                file_path = os.path.join(subdir, file)
                pitch_shift(file_path, n_steps=2)
                time_stretch(file_path, rate=1.1)
                
root_directory = 'VoxCeleb_gender/Final Data'
process_directory(root_directory)
